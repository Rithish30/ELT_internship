# %%
import json
import os
import random
import time

# %%
def loadsjson():
    #load records.json
    if os.path.exists('records.json'):
        if os.stat("records.json").st_size == 0:
            return {}
        else:
            f=open("records.json","r")
            records=json.loads(f.read())
            return records    
    else:
        return {}

# %%
def dumpsjson(records):
#to save all the changes made in edited file
        txt=json.dumps(records)
        with open('records.json','w') as fd:
          fd.write(txt)
        print('***************  Record Saved  ***************')

# %%
def buyproduct(prodname,records):
    #This function is used for buy a product from the Inventry Management System.
    sales = {}
    AllProd={}
    c=0
    flag=True
    custname=input("Enter your name")
    for i in records:
        if prodname == records[i]['name']:
            AllProd[i]=f"Name=> {records[i]['name']} Price:=> {records[i]['price']}"
    if len(AllProd)==0:
        print("Product Not Found  ")
    elif len(AllProd)==1:
        agree=input(f"Do you want to buy {list(AllProd.values())[0]} y/n and enter q to quit  ").lower()
        t=list(AllProd.values())[0]
        print(t)
        if agree=='y':
            quant=int(input("Enter The Quantity of the product  "))
            key=list(AllProd.keys())[0]
            print(key)
            for i in records:
                if i==key:
                    if records[i]['quantity']>=quant:
                        price=records[i]['price']
                        total_price=quant*price-((price*records[i]['discount'])/100)
                        pay=input(f"You Need To pay {quant*price-((price*records[i]['discount'])/100)} \nYou Want to pay or not y/n")
                        if pay=='y':
                            random_id = str(random.randint(100,999))
                            current_time=time.ctime()
                            sales[random_id]={}
                            sales[random_id]["cust_name"]=custname
                            sales[random_id]["purchase_time"]=current_time
                            sales[random_id]["Product ID"]=i
                            sales[random_id]["Product Name"]=records[i]["name"]
                            sales[random_id]["Price"]=records[i]["price"]
                            sales[random_id]["Quantity"]=quant
                            sales[random_id]["Total Price"]=total_price
                            print("*************** Successfully Purchased ***************")
                            records[i]['quantity']-=quant
                            c+=1
                        else:
                            print("*************** Order Cancelled ***************")
                    else:
                        print(f"Sorry We have Only {records[i]['quantity']} product  ")
        elif agree=='q':
            flag=False
    elif len(AllProd)>1:
        print(f"There are {len(AllProd)} with name:=>{prodName} \nDo you want to buy? Choose the number that you want to buy Or enter q to exit  ")
        j=0
        product={}
        for i in AllProd:
            print(f"{j}:=> {AllProd[i]}  ")
            product[j]=AllProd[i]
            j+=1 
        k=input(f"{list(range(j))}  ")
        key=product[int(k)]
        if k!='q':
            quant=int(input("Enter The Quantity of the product  "))
            for i in records:
                if i==key:
                    if records[i]['quantity']>=quant:
                        price=records[i]['price']
                        total_price=quant*price-((price*records[i]['discount'])/100)
                        pay=input(f"You Need To pay {quant*price-((price*records[i]['discount'])/100)} \nYou Want to pay or not y/n")
                        if pay=='y':
                            random_id = str(random.randint(100,999))
                            current_time=time.ctime()
                            sales[random_id]={}
                            sales[random_id]["cust_name"]=custname
                            sales[random_id]["purchase_time"]=current_time
                            sales[random_id]["Product ID"]=i
                            sales[random_id]["Product Name"]=records[i]["name"]
                            sales[random_id]["Price"]=records[i]["price"]
                            sales[random_id]["Quantity"]=quant
                            sales[random_id]["Total Price"]=total_price
                            print("*************** Successfully Purchased ***************")
                            records[i]['quantity']-=quant
                            c+=1
                        else:
                            print("*************** Order Cancelled ***************")
                    else:
                        print(f"Sorry We have Only {records[i]['quantity']} product  ")
        else:
            flag=False
    if c>=1:
        print(sales)
        sales_json = json.dumps(sales)
        print(sales_json)
        sf = open("sales.json",'w')
        sf.write(sales_json)
        sf.close()
    return c

# %%
def operations(t,records):
#this function is used to confirm the operation the user wants to perform
    c=0
    if not t:
        print("records are empty")
        return c
        
    else:
        flag=True
        op=input("Enter 1 to buy a product, q to exit  ")
        while op!='q':
            if op=='1':
                prodname=input("enter product name")
                c=buyproduct(prodname,records)  
            else:
                print("Wrong Input \nPlease Enter again:=>  ")
            op=input("Enter 1 to add a record, 2 to buy a product, q to exit  ")
            
    return c

# %%
if __name__=='__main__':
    records=loadsjson()
    c=0
    while True: 
        t=True
        if records=={}:
            t=False
            print("Records are Empty")
        else:
            inp=input("do you want to take a look at all the products? y/n").lower()
            if inp=='y':
                for i in records:
                    print(i,":=>",records[i])
        c = operations(t,records) 
        if input("Do you want to exit? y/n  ").lower()=='y':
                break
    if c>=1:
        dumpsjson(records)
        
        

    print("\n\n*********** Thank you For using ***************")
# Out:
# do you want to take a look at all the products? y/ny
# 1111 :=> {'name': 'Organic Cotton Crew-Neck T-shirt', 'brand': 'tommy hilfiger', 'age': 'adult', 'gender': 'men', 'category': 'topwear', 'variety': 't-shirt', 'material': 'cotton', 'color': 'blue', 'size': 's', 'price': 1999, 'quantity': 5, 'discount': 20}
# 1112 :=> {'name': 'graphic-print-crew-neck-t-shirt', 'brand': 'wolfpack', 'age': 'adult', 'gender': 'men', 'category': 'topwear', 'variety': 't-shirt', 'material': 'cotton', 'color': 'grey', 'size': 'm', 'price': 1999, 'quantity': 5, 'discount': 20}
# 1113 :=> {'name': 'Brand Embroidered Organic Cotton Sweatshirt', 'brand': 'tommy hilfiger', 'age': 'adult', 'gender': 'men', 'category': 'topwear', 'variety': 'Sweatshirt', 'material': 'cotton', 'color': 'blue', 'size': 'l', 'price': 1999, 'quantity': 5, 'discount': 20}
# 1114 :=> {'name': 'Polo T-shirt with Contrast Tipping', 'brand': 'tommy hilfiger', 'age': 'adult', 'gender': 'men', 'category': 'topwear', 'variety': 't-shirt', 'material': 'cotton', 'color': 'black', 'size': 'xl', 'price': 1999, 'quantity': 5, 'discount': 20}
# 1115 :=> {'name': 'Logo Print Hoodie with Kangaroo Pocket', 'brand': 'tommy hilfiger', 'age': 'adult', 'gender': 'men', 'category': 'topwear', 'variety': 'Hoodie', 'material': 'cotton', 'color': 'blue', 'size': 'xxl', 'price': 1999, 'quantity': 5, 'discount': 20}
# 1116 :=> {'name': 'Printed Crew-Neck T-shirt', 'brand': 'vanhuesen', 'age': 'adult', 'gender': 'men', 'category': 'topwear', 'variety': 't-shirt', 'material': 'cotton', 'color': 'blue', 'size': 'm', 'price': 1999, 'quantity': 5, 'discount': 20}
# 1117 :=> {'name': 'Printed Slim Fit Polo T-shirt', 'brand': 'vanhuesen', 'age': 'adult', 'gender': 'men', 'category': 'topwear', 'variety': 't-shirt', 'material': 'cotton', 'color': 'white', 'size': 'l', 'price': 1999, 'quantity': 5, 'discount': 20}
# 1118 :=> {'name': 'Polo T-shirt with Patch Pocket', 'brand': 'vanhuesen', 'age': 'adult', 'gender': 'men', 'category': 'topwear', 'variety': 't-shirt', 'material': 'cotton', 'color': 'blue', 'size': 'xl', 'price': 1999, 'quantity': 5, 'discount': 20}
# 1119 :=> {'name': 'Printed Slim Fit Shirt', 'brand': 'vanhuesen', 'age': 'adult', 'gender': 'men', 'category': 'topwear', 'variety': 'shirt', 'material': 'cotton', 'color': 'brown', 'size': 'xxl', 'price': 1999, 'quantity': 5, 'discount': 20}
# 1120 :=> {'name': 'colourblock-round-neck-pullover', 'brand': 'club-york', 'age': 'adult', 'gender': 'men', 'category': 'topwear', 'variety': 'pullover', 'material': 'cotton', 'color': 'black', 'size': 's', 'price': 2399, 'quantity': 5, 'discount': 20}
# 1121 :=> {'name': 'colourblock-round-neck-pullover', 'brand': 'club-york', 'age': 'adult', 'gender': 'men', 'category': 'topwear', 'variety': 'pullover', 'material': 'cotton', 'color': 'black', 'size': 'm', 'price': 2399, 'quantity': 5, 'discount': 20}
# 1122 :=> {'name': 'heathered-single-breasted-slim-fit-blazer', 'brand': 'Marks & Spencer', 'age': 'adult', 'gender': 'men', 'category': 'topwear', 'variety': 'blazer', 'material': 'polyester', 'color': 'black', 'size': 'm', 'price': 6999, 'quantity': 5, 'discount': 20}
# 1123 :=> {'name': 'mandarin-collar-jacket-with-insert-pockets', 'brand': 'manyavar', 'age': 'adult', 'gender': 'men', 'category': 'topwear', 'variety': 'jacket', 'material': 'silk', 'color': 'beige', 'size': 'm', 'price': 4999, 'quantity': 2, 'discount': 20}
# 1124 :=> {'name': 'slim-fit-shirt-with-cutaway-collar', 'brand': 'french-connection', 'age': 'adult', 'gender': 'men', 'category': 'topwear', 'variety': 'shirt', 'material': 'cotton', 'color': 'green', 'size': 'm', 'price': 2499, 'quantity': 5, 'discount': 20}
# 1125 :=> {'name': 'Heathered Track Pants with Contrast Taping', 'brand': 'TEAMSPIRIT', 'age': 'adult', 'gender': 'men', 'category': 'bottomwear', 'variety': 'trackpant', 'material': 'cotton', 'color': 'black', 'size': 'm', 'price': 999, 'quantity': 5, 'discount': 20}
# 1126 :=> {'name': 'Camouflage Print Slim Fit Jogger Pants', 'brand': 'IVOC', 'age': 'adult', 'gender': 'men', 'category': 'bottomwear', 'variety': 'joggers', 'material': 'cotton', 'color': 'green', 'size': 'm', 'price': 1299, 'quantity': 5, 'discount': 20}
# 1127 :=> {'name': 'Mid-Rise QuickDry Shorts with Insert Pockets', 'brand': 'PERFORMAX', 'age': 'adult', 'gender': 'men', 'category': 'bottomwear', 'variety': 'Shorts', 'material': 'cotton', 'color': 'blue', 'size': 'm', 'price': 599, 'quantity': 5, 'discount': 20}
# 1128 :=> {'name': 'Slim Fit Flat-Front Chinos', 'brand': 'NETPLAY', 'age': 'adult', 'gender': 'men', 'category': 'bottomwear', 'variety': 'Chinos', 'material': 'cotton', 'color': 'khaku', 'size': 's', 'price': 1999, 'quantity': 5, 'discount': 20}
# 1129 :=> {'name': 'Washed Slim Fit Jeans with Whiskers', 'brand': 'LEE COOPER', 'age': 'adult', 'gender': 'men', 'category': 'bottomwear', 'variety': 'Jeans', 'material': 'cotton', 'color': 'indigo', 'size': 's', 'price': 1999, 'quantity': 5, 'discount': 20}
# 1130 :=> {'name': 'Bold Extreme IDP Low-Top Lace-Up Casual Shoes', 'brand': 'puma', 'age': 'adult', 'gender': 'men', 'category': 'footwear', 'variety': 'Shoes', 'material': 'Rubber sole', 'color': 'black', 'size': '9', 'price': 2999, 'quantity': 5, 'discount': 20}
# 1131 :=> {'name': 'LiteRide Clogs with Slingback', 'brand': 'crocs', 'age': 'adult', 'gender': 'men', 'category': 'footwear', 'variety': 'sandals', 'material': 'Croslite', 'color': 'black', 'size': '9', 'price': 2999, 'quantity': 5, 'discount': 20}
# 1132 :=> {'name': 'Nike men flip flops & slippers black 9', 'brand': 'puma', 'age': 'adult', 'gender': 'men', 'category': 'footwear', 'variety': 'flip flops', 'material': 'Rubber sole', 'color': 'black', 'size': '9', 'price': 2099, 'quantity': 5, 'discount': 20}
# 1133 :=> {'name': 'Fluidflow 2.0 Lace-Up Running Shoes', 'brand': 'ADIDAS', 'age': 'adult', 'gender': 'women', 'category': 'footwear', 'variety': 'Shoes', 'material': 'Rubber sole', 'color': 'white', 'size': '5', 'price': 2099, 'quantity': 5, 'discount': 20}
# 1134 :=> {'name': 'Eva Slides with Branding', 'brand': 'superdry', 'age': 'adult', 'gender': 'women', 'category': 'footwear', 'variety': 'flip flops', 'material': 'Rubber sole', 'color': 'white', 'size': '5', 'price': 2099, 'quantity': 5, 'discount': 20}
# 1135 :=> {'name': 'Slip-On Outdoor Sandals', 'brand': 'campus', 'age': 'adult', 'gender': 'women', 'category': 'footwear', 'variety': 'sandals', 'material': 'Rubber sole', 'color': 'black', 'size': '5', 'price': 2099, 'quantity': 5, 'discount': 20}
# 1136 :=> {'name': 'Beaded Foldover Clutch with Chain Sling Strap', 'brand': 'diwah', 'age': 'adult', 'gender': 'women', 'category': 'handbags', 'variety': 'Foldover clutch', 'material': 'cotton', 'color': 'black', 'size': 'FS', 'price': 2999, 'quantity': 5, 'discount': 20}
# 1137 :=> {'name': 'Aztec Embroidered Sling Bag with Chain Strap', 'brand': 'diwah', 'age': 'adult', 'gender': 'women', 'category': 'handbags', 'variety': 'Sling', 'material': 'cotton', 'color': 'black', 'size': 'FS', 'price': 2099, 'quantity': 4, 'discount': 20}
# 1138 :=> {'name': 'Cowl-Neck Pullover with Raglan Sleeves', 'brand': 'CLUB YORK', 'age': 'adult', 'gender': 'women', 'category': 'topwear', 'variety': 'sweaters & cardigans', 'material': 'acrylic', 'color': 'green', 'size': 's', 'price': 999, 'quantity': 4, 'discount': 20}
# 1139 :=> {'name': 'Floral Print A-line Kurta', 'brand': 'antaran', 'age': 'adult', 'gender': 'women', 'category': 'topwear', 'variety': 'kurtas', 'material': 'rayon', 'color': 'green', 'size': 's', 'price': 999, 'quantity': 4, 'discount': 20}
# 1140 :=> {'name': 'Textured Thermal Leggings', 'brand': 'diwah', 'age': 'adult', 'gender': 'women', 'category': 'innerwear', 'variety': 'Leggings', 'material': 'cotton', 'color': 'black', 'size': 's', 'price': 599, 'quantity': 5, 'discount': 20}
# 1141 :=> {'name': 'Graphic Print Crew-Neck T-shirt', 'brand': 'dnmx', 'age': 'kids', 'gender': 'boys', 'category': 'topwear', 'variety': 't-shirts', 'material': 'cotton', 'color': 'red', 'size': 's', 'price': 399, 'quantity': 5, 'discount': 20}
# 1142 :=> {'name': 'Tulle Fit & Flare Dress with Sequinned Panel', 'brand': 'antaran', 'age': 'kids', 'gender': 'girls', 'category': 'topwear', 'variety': 'frocks', 'material': 'Tulle', 'color': 'pink', 'size': 's', 'price': 599, 'quantity': 5, 'discount': 20}
# 1143 :=> {'name': 'Logo Print Hoodie with Kangaroo Pocket', 'brand': 'tommy hilfiger', 'age': 'adult', 'gender': 'men', 'category': 'topwear', 'variety': 'hoodie', 'color': 'grey', 'size': 'm', 'price': 1299, 'quantity': 5, 'discount': 20}
# Enter 1 to buy a product, q to exit  1
# enter product nameSlim Fit Flat-Front Chinos
# Enter your nameRaj
# Do you want to buy Name=> Slim Fit Flat-Front Chinos Price:=> 1999 y/n and enter q to quit  y
# Name=> Slim Fit Flat-Front Chinos Price:=> 1999
# Enter The Quantity of the product  1
# 1128
# You Need To pay 1599.2
# You Want to pay or not y/ny
# *************** Successfully Purchased ***************
# {'257': {'cust_name': 'Raj', 'purchase_time': 'Mon Sep  6 17:14:03 2021', 'Product ID': '1128', 'Product Name': 'Slim Fit Flat-Front Chinos', 'Price': 1999, 'Quantity': 1, 'Total Price': 1599.2}}
# {"257": {"cust_name": "Raj", "purchase_time": "Mon Sep  6 17:14:03 2021", "Product ID": "1128", "Product Name": "Slim Fit Flat-Front Chinos", "Price": 1999, "Quantity": 1, "Total Price": 1599.2}}
# Enter 1 to add a record, 2 to buy a product, q to exit  q
# Do you want to exit? y/n  y
# ***************  Record Saved  ***************
#
#
# *********** Thank you For using ***************
